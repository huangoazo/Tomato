# %%
# original one

import numpy as np
import random as r
import matplotlib.pyplot as plt
from collections import Counter

n=100000
N=100000
U=100
peple=np.full((N),U)
for i in range(0,n):
    ll=0
    result=0
    result=r.sample(range(0,N),N)
    # print(len(result) == len(set((result))))
    for loss_ in result[:N//2]:
        if peple[loss_]!=0:
            peple[loss_]=peple[loss_]-1
        else:
            ll+=1
    for win_ in result[N//2:]:
        if ll >0:
            pass
        else:
            peple[win_]=peple[win_]+1
        ll-=1
    # print(np.mean(peple))
    print(i)
coin=Counter(peple)
value=list(coin.keys())
num=np.array(list(coin.values()))/N

plt.scatter(value,num)
# plt.plot(value,num)

T=np.array(list(range(0,500)))
p=(U/(U+1))**T/(U+1)
plt.plot(T,p,T,np.exp(-T/U)/U)
plt.show()

# %%
import numpy as np
import random as r
import matplotlib.pyplot as plt
from collections import Counter


n=1000 # play times
N=10000 # people
# ax = plt.axes()
# ax.tick_params(axis='x', colors='white',labelsize=15)
# ax.tick_params(axis='y', colors='white',labelsize=15)


for U in [5]: # initial money
    peple=np.full((N),U)
    a = N//2
    for i in range(0,n):
        ll=0
        result=r.sample(range(0,N),N)
        # print(len(result) == len(set((result))))

    #     for loss_ in result[:N//2]:
    #         if peple[loss_]!=0:
    #             peple[loss_]-=1
    #         else:
    #             ll+=1
    #     peple[result[N//2+ll:]]+=1

#         if i in [999]: # print figure
#             coin=Counter(peple)
#             value=list(coin.keys())
#             num=np.array(list(coin.values()))/N
            

# #             plt.scatter(value,num)

#             T=np.array(list(range(0,50)))
#             p=(U/(U+1))**T/(U+1)
#             plt.plot(T,p)

    #         plt.show()

        for j in range(0,a):
            if (peple[result[j]]>10) & (peple[result[j+a]]<20):
                peple[result[j]]-=1
                peple[result[j+a]]+=1
            
    




# print(np.mean(peple))
#     print(i)
coin=Counter(peple)
value=list(coin.keys())
num=np.array(list(coin.values()))/N

# print(coin)
plt.scatter(value,num)
# plt.plot(value,num)

T=np.array(list(range(0,50)))
p=(U/(U+1))**T/(U+1)
# plt.plot(T,p,T,np.exp(-T/U)/U)
plt.plot(T,p)
plt.show()

# %%
for U in [5]:
    T=np.linspace(0,50,10**4)
    p=(U/(U+1))**T/(U+1)
    plt.plot(T,p)

plt.show()

# %%
ax = plt.axes()
ax.tick_params(axis='x', colors='white',labelsize=15)
ax.tick_params(axis='y', colors='white',labelsize=15)


T=np.linspace(0.0001,0.99999,10**2)
m = T*np.log(T)+(1-T)*np.log(1-T)
plt.plot(T,-m)
plt.ylim(0)
plt.show()

# %%
plt.scatter(value,num)
# plt.plot(value,num)

T=np.array(list(range(0,50)))
p=(U/(U+1))**T/(U+1)
plt.plot(-T+10,p,-T+10,np.exp(-T/U)/U)
plt.show()

# %%
a = np.linspace(-np.pi*4,np.pi*4,10000)
plt.plot(a,np.cos(1*a))
plt.ylim(-2,2)
plt.xlim(-np.pi*4,np.pi*4)
plt.plot([0,0],[-10,10],'--')
plt.show()
plt.plot(a,np.cos(1*a+np.pi/2))
plt.ylim(-2,2)
plt.xlim(-np.pi*4,np.pi*4)
plt.plot([0,0],[-10,10],'--')
plt.plot([-np.pi/2,-np.pi/2],[-10,10],'r--')

# %%
a = np.linspace(-np.pi*4,np.pi*4,10000)
plt.plot(a,np.cos(1*a),'b')
plt.plot(a,np.cos(1.2*a),'r')
plt.ylim(-2,2)
plt.xlim(-np.pi*4,np.pi*4)
plt.plot([0,0],[-10,10],'b--')
plt.plot([0,0],[-10,10],'r--')
plt.xlim(-7,7)
plt.show()
a = np.linspace(-np.pi*4,np.pi*4,10000)
plt.plot(a,np.cos(1*a-2*np.pi/1.2),'b')
plt.plot(a,np.cos(1.2*a-2*np.pi*1),'r')
plt.ylim(-2,2)
plt.xlim(-np.pi*4,np.pi*4)
plt.plot([-2*np.pi+2*np.pi/1.2,-2*np.pi+2*np.pi/1.2],[-10,10],'b--')
plt.plot([0,0],[-10,10],'r--')
plt.xlim(-7,7)
plt.show()

a = np.linspace(-np.pi*4,np.pi*4,10000)
plt.plot(a,np.cos(1*a+np.pi/2),'b')
plt.plot(a,np.cos(1*a),'r')
plt.ylim(-2,2)
plt.xlim(-np.pi*4,np.pi*4)
plt.plot([-np.pi/2,-np.pi/2],[-10,10],'b--')
plt.plot([0,0],[-10,10],'r--')
plt.xlim(-7,7)
plt.show()
a = np.linspace(-np.pi*4,np.pi*4,10000)
plt.plot(a,np.cos(1*a+np.pi/2-2*np.pi/1),'b')
plt.plot(a,np.cos(1*a-np.pi*2),'r')
plt.ylim(-2,2)
plt.xlim(-np.pi*4,np.pi*4)
plt.plot([-np.pi/2,-np.pi/2],[-10,10],'b--')
plt.plot([0,0],[-10,10],'r--')
plt.xlim(-7,7)
plt.show()

# %%
a = np.linspace(-np.pi*10,np.pi*10,10000)
plt.plot(a,2+2*np.cos(1*a),'b')
plt.ylim(0,5)
plt.xlim(-np.pi*10,np.pi*10)
for i in range(-2,3):
    plt.plot([i*2*np.pi,i*2*np.pi],[-10,10],'r--')
# plt.plot([np.pi,np.pi],[-10,10],'k--')
# plt.xlim(-7,7)
plt.show()

# %%
a = np.array(np.linspace(0,10,10**4*8))
np.shape(a),np.shape(a.reshape(1,-1))
a=a.reshape(-1,1)
b=a.reshape(1,-1)
np.shape(a*b)
